# %% [markdown]
# ### Creating new features: Interaction terms, quadratic terms, etc.

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# Some data exploration

# %%
df1 = pd.read_csv("../data/Training_Data_allVar.csv")

# %%
# Out:
# 6240
